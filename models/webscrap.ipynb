# %%
pip install bs4

# %%
pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL = "https://www.amazon.in/gp/bestsellers/electronics"

# %%
HEADERS = { 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36','Accept-Language': 'en-US,en;q=0.5'
}

# %%
webpage = requests.get(URL, headers=HEADERS)

# %%
type(webpage.content)
# Out:
# bytes

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(webpage.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
# Find all <a> tags with a specific class
links = soup.find_all("a", attrs={"class": "a-link-normal aok-block"})

# Loop through each link and print the href and title
for link in links:
    href = link.get("href")  # Get the href (link) from the <a> tag
    title_div = link.find("div", class_="_cDEzb_p13n-sc-css-line-clamp-3_g3dy1")  # Get the product title

    if href and title_div:
        full_link = "https://www.amazon.in" + href  # Complete the relative link with the base URL
        title = title_div.get_text(strip=True)  # Extract the product title text
        print("Product Title:", title)
        print("Product Link:", full_link)
        print("-" * 80)
# Out:
# Product Title: Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB Storage) | 50MP Dual Camera | Bigger 6.7" HD+ Display | 5000mAh Battery | 25W Fast Charging | 2 Gen OS Upgrade & 4 Year Security Update | Without Charger
# Product Link: https://www.amazon.in/Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6/ref=zg_bs_g_electronics_d_sccl_1/257-1272314-1256546?psc=1
# --------------------------------------------------------------------------------
# Product Title: Oneplus Bullets Z2 Bluetooth Wireless in Ear Earphones with Mic, Bombastic Bass - 12.4 mm Drivers, 10 Mins Charge - 20 Hrs Music, 30 Hrs Battery Life, IP55 Dust and Water Resistant (Magico Black)
# Product Link: https://www.amazon.in/Oneplus-Bluetooth-Wireless-Earphones-Bombastic/dp/B09TVVGXWS/ref=zg_bs_g_electronics_d_sccl_4/257-1272314-1256546?psc=1
# --------------------------------------------------------------------------------
# ...

# %%
# Example list of relative URLs (you will get this from the previous scraping)
relative_links = ["/Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6", "/Another-Product-Link/dp/B0ABC12345"]

# Base URL
base_url = "https://www.amazon.in"

# List to store full URLs
product_list = []

# Concatenate base URL with each relative URL
for rel_link in relative_links:
    full_link = base_url + rel_link
    product_list.append(full_link)

# Print the list of full URLs
print(product_list)
# Out:
# ['https://www.amazon.in/Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6', 'https://www.amazon.in/Another-Product-Link/dp/B0ABC12345']

# %%
for url in product_list:
    new_webpage = requests.get(url, headers=HEADERS)

    if new_webpage.status_code == 200:
        # You can now parse it with BeautifulSoup or do further processing
        soup = BeautifulSoup(new_webpage.content, "html.parser")
        # Add your scraping logic here
        print(f"Scraped data from: {url}")
    else:
        print(f"Failed to retrieve {url} - Status Code:", new_webpage.status_code)
# Out:
# Scraped data from: https://www.amazon.in/Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6
# Failed to retrieve https://www.amazon.in/Another-Product-Link/dp/B0ABC12345 - Status Code: 404

# %%
for link in links:
    href = link.get("href")
    print("Scraped href:", href)
# Out:
# Scraped href: /Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6/ref=zg_bs_g_electronics_d_sccl_1/257-1272314-1256546?psc=1
# Scraped href: /Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6/ref=zg_bs_g_electronics_d_sccl_1/257-1272314-1256546?psc=1
# Scraped href: /realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F18Y9YMX/ref=zg_bs_g_electronics_d_sccl_2/257-1272314-1256546?psc=1
# Scraped href: /realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F18Y9YMX/ref=zg_bs_g_electronics_d_sccl_2/257-1272314-1256546?psc=1
# Scraped href: /realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F1XMGQSP/ref=zg_bs_g_electronics_d_sccl_3/257-1272314-1256546?psc=1
# Scraped href: /realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F1XMGQSP/ref=zg_bs_g_electronics_d_sccl_3/257-1272314-1256546?psc=1
# Scraped href: /Oneplus-Bluetooth-Wireless-Earphones-Bombastic/dp/B09TVVGXWS/ref=zg_bs_g_electronics_d_sccl_4/257-1272314-1256546?psc=1
# ...

# %%
valid_links = []

for link in links:
    href = link.get("href")
    if href and "/dp/" in href:
        full_link = "https://www.amazon.in" + href
        valid_links.append(full_link)

# %%
for url in valid_links:
    response = requests.get(url, headers=HEADERS)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        print(f"Success: {url}")
        # Extract info here...
    else:
        print(f"Failed to retrieve {url} - Status Code: {response.status_code}")
# Out:
# Success: https://www.amazon.in/Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6/ref=zg_bs_g_electronics_d_sccl_1/257-1272314-1256546?psc=1
# Success: https://www.amazon.in/Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6/ref=zg_bs_g_electronics_d_sccl_1/257-1272314-1256546?psc=1
# Success: https://www.amazon.in/realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F18Y9YMX/ref=zg_bs_g_electronics_d_sccl_2/257-1272314-1256546?psc=1
# Success: https://www.amazon.in/realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F18Y9YMX/ref=zg_bs_g_electronics_d_sccl_2/257-1272314-1256546?psc=1
# Success: https://www.amazon.in/realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F1XMGQSP/ref=zg_bs_g_electronics_d_sccl_3/257-1272314-1256546?psc=1
# Success: https://www.amazon.in/realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F1XMGQSP/ref=zg_bs_g_electronics_d_sccl_3/257-1272314-1256546?psc=1
# ...

# %%
from bs4 import BeautifulSoup
import requests

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

url = "https://www.amazon.in/dp/B0DFY3XCB6"  # Example product page
response = requests.get(url, headers=HEADERS)

if response.status_code == 200:
    new_soup = BeautifulSoup(response.content, "html.parser")
    title_element = new_soup.find("span", attrs={"id": "productTitle"})
    if title_element:
        product_title = title_element.text.strip()
        print("Product Title:", product_title)
    else:
        print("Product title not found on the page.")
else:
    print("Failed to fetch the product page. Status:", response.status_code)
# Out:
# Failed to fetch the product page. Status: 500

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
    "DNT": "1",  # Do Not Track Request Header
    "Connection": "keep-alive",
}

# %%
import time
time.sleep(2)  # sleep for 2 seconds between requests

# %%
try:
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        new_soup = BeautifulSoup(response.content, "html.parser")
        title = new_soup.find("span", attrs={"id": "productTitle"}).text.strip()
        print("Product Title:", title)
    else:
        print(f"Failed to fetch the product page. Status: {response.status_code}")
except Exception as e:
    print("Error occurred:", e)
# Out:
# Product Title: Galaxy M05 (Mint Green, 4GB RAM, 64 GB Storage) | 50MP Dual Camera | Bigger 6.7" HD+ Display | 5000mAh Battery | 25W Fast Charging | 2 Gen OS Upgrade & 4 Year Security Update | Without Charger

# %%
price_element = new_soup.find("span", class_=["a-price", "a-text-price", "a-size-medium"])

if price_element:
    price = price_element.find("span", class_="a-offscreen")
    if price:
        print("Product Price:", price.text.strip())
    else:
        print("Price not found inside.")
else:
    print("Price block not found.")
# Out:
# Price not found inside.

# %%
print(new_soup.prettify()[:1000])  # Print first 1000 characters
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
# ...

# %%
price_element = new_soup.find("span", class_="a-price")

if price_element:
    price = price_element.find("span", class_="a-offscreen")
    if price:
        print("Product Price:", price.text.strip())
    else:
        print("Price span not found inside a-price.")
else:
    print("a-price container not found.")
# Out:
# Product Price: ₹6,299.00

# %%
if "captcha" in new_soup.text.lower() or "robot check" in new_soup.title.string.lower():
    print("Amazon blocked the request with a bot check.")

# %%
rating_element = new_soup.find("span", attrs={"class": "a-icon-alt"})

if rating_element:
    rating = rating_element.text.strip()
    print("Product Rating:", rating)
else:
    print("Rating not found.")
# Out:
# Product Rating: 4.0 out of 5 stars

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
def get_price(soup):
    try:
        price = soup.find("span", attrs={'id': 'priceblock_ourprice'})
        if price:
            return price.text.strip()

        price = soup.find("span", attrs={'id': 'priceblock_dealprice'})
        if price:
            return price.text.strip()

        price = soup.find("span", attrs={'id': 'priceblock_saleprice'})
        if price:
            return price.text.strip()

        # Try newer a-price class
        price = soup.find("span", class_="a-price")
        if price:
            return price.find("span", class_="a-offscreen").text.strip()

    except:
        pass

    return ""

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# Functions (same as you defined, with robustness added)
def get_title(soup):
    try:
        title = soup.find("span", attrs={"id": 'productTitle'})
        return title.text.strip()
    except:
        return ""

def get_price(soup):
    try:
        price = soup.find("span", attrs={'id': 'priceblock_ourprice'})
        if price:
            return price.text.strip()

        price = soup.find("span", attrs={'id': 'priceblock_dealprice'})
        if price:
            return price.text.strip()

        price = soup.find("span", attrs={'id': 'priceblock_saleprice'})
        if price:
            return price.text.strip()

        # Try class-based price
        price = soup.find("span", class_="a-price")
        if price:
            return price.find("span", class_="a-offscreen").text.strip()
    except:
        return ""
    return ""

def get_rating(soup):
    try:
        rating = soup.find("span", class_="a-icon-alt")
        return rating.text.strip()
    except:
        return ""

def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id': 'acrCustomerReviewText'})
        return review_count.text.strip()
    except:
        return ""

def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id': 'availability'})
        return available.find("span").text.strip()
    except:
        return "Not Available"

# Main Function
if __name__ == '__main__':

    HEADERS = ({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US, en;q=0.5'
    })

    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"

    webpage = requests.get(URL, headers=HEADERS)

    soup = BeautifulSoup(webpage.content, "html.parser")

    links = soup.find_all("a", attrs={'class': 'a-link-normal s-no-outline'})
    links_list = []

    for link in links:
        href = link.get('href')
        if href:
            links_list.append(href)

    d = {"title": [], "price": [], "rating": [], "reviews": [], "availability": []}

    for link in links_list:
        full_url = "https://www.amazon.com" + link
        print(f"Fetching: {full_url}")

        try:
            new_webpage = requests.get(full_url, headers=HEADERS)

            if new_webpage.status_code == 200:
                new_soup = BeautifulSoup(new_webpage.content, "html.parser")
                d['title'].append(get_title(new_soup))
                d['price'].append(get_price(new_soup))
                d['rating'].append(get_rating(new_soup))
                d['reviews'].append(get_review_count(new_soup))
                d['availability'].append(get_availability(new_soup))
            else:
                print(f"Failed to retrieve {full_url} - Status Code: {new_webpage.status_code}")
                continue

        except Exception as e:
            print(f"Error fetching {full_url} - {e}")
            continue

    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df.dropna(subset=['title'], inplace=True)
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)
    print("Scraping Completed. Data saved to amazon_data.csv")
# Out:
# Scraping Completed. Data saved to amazon_data.csv
# <ipython-input-46-833795f41104>:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   amazon_df['title'].replace('', np.nan, inplace=True)

# %%
print(webpage.text[:500])  # Display the first 500 characters of the response
# Out:
# <!--
#         To discuss automated access to Amazon data please contact api-services-support@amazon.com.
#         For information about migrating to our APIs refer to our Marketplace APIs at https://developer.amazonservices.com/ref=rm_5_sv, or our Product Advertising API at https://affiliate-program.amazon.com/gp/advertising/api/detail/main.html/ref=rm_5_ac for advertising use cases.
# -->
# <!doctype html>
# <html>
# <head>
#   <meta charset="utf-8">
#   <meta http-equiv="x-ua-compatible" content="ie=edge">

# %%
print(new_soup.prettify()[:1000])  # Print the first 1000 characters of the soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
# ...

# %%
print(amazon_df)
# Out:
# Empty DataFrame
# Columns: [title, price, rating, reviews, availability]
# Index: []

# %% [markdown]
# # Complete code

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np

# Define headers for requests to make it look like a real browser request
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5'
}

# Function to extract the title of the product
def get_title(soup):
    try:
        title = soup.find("span", attrs={"id": 'productTitle'})
        return title.text.strip() if title else "No title found"
    except:
        return "No title found"

# Function to extract the price of the product
def get_price(soup):
    try:
        price = soup.find("span", attrs={'id': 'priceblock_ourprice'}) or \
                soup.find("span", attrs={'id': 'priceblock_dealprice'}) or \
                soup.find("span", attrs={'id': 'priceblock_saleprice'}) or \
                soup.find("span", class_="a-price")
        if price:
            price = price.find("span", class_="a-offscreen") if price else price
            return price.text.strip() if price else "No price found"
        else:
            return "No price found"
    except:
        return "No price found"

# Function to extract the rating of the product
def get_rating(soup):
    try:
        rating = soup.find("span", class_="a-icon-alt")
        return rating.text.strip() if rating else "No rating found"
    except:
        return "No rating found"

# Function to extract the review count of the product
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id': 'acrCustomerReviewText'})
        return review_count.text.strip() if review_count else "No reviews found"
    except:
        return "No reviews found"

# Function to extract availability of the product
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id': 'availability'})
        return available.find("span").text.strip() if available else "Not Available"
    except:
        return "Not Available"

# Main function to scrape data from Amazon
def scrape_amazon():
    # URL for Amazon's electronics best-sellers
    URL = "https://www.amazon.in/gp/bestsellers/electronics"
    webpage = requests.get(URL, headers=HEADERS)

    if webpage.status_code != 200:
        print("Failed to fetch the webpage.")
        return

    soup = BeautifulSoup(webpage.content, "html.parser")

    # Extract product links from the best-sellers page
    links = soup.find_all("a", attrs={'class': 'a-link-normal aok-block'})
    links_list = []

    # Append full URLs for each product
    for link in links:
        href = link.get('href')
        if href:
            full_url = "https://www.amazon.in" + href
            links_list.append(full_url)

    # Create a dictionary to store scraped data
    data = {
        "title": [],
        "price": [],
        "rating": [],
        "reviews": [],
        "availability": []
    }

    # Loop through the product links and scrape individual product pages
    for full_url in links_list:
        print(f"Scraping: {full_url}")

        try:
            new_webpage = requests.get(full_url, headers=HEADERS)
            if new_webpage.status_code == 200:
                new_soup = BeautifulSoup(new_webpage.content, "html.parser")

                # Extract product details
                data['title'].append(get_title(new_soup))
                data['price'].append(get_price(new_soup))
                data['rating'].append(get_rating(new_soup))
                data['reviews'].append(get_review_count(new_soup))
                data['availability'].append(get_availability(new_soup))
            else:
                print(f"Failed to retrieve {full_url} - Status Code: {new_webpage.status_code}")
                continue

        except Exception as e:
            print(f"Error fetching {full_url}: {e}")
            continue

        # Sleep between requests to avoid hitting Amazon too frequently
        time.sleep(2)

    # Convert data to a pandas DataFrame
    amazon_df = pd.DataFrame.from_dict(data)

    # Handle missing data and drop rows with missing titles
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df.dropna(subset=['title'], inplace=True)

    # Save to CSV
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)
    print("Scraping completed. Data saved to amazon_data.csv")

# Run the scraper
if __name__ == '__main__':
    scrape_amazon()
# Out:
# Scraping: https://www.amazon.in/Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6/ref=zg_bs_g_electronics_d_sccl_1/257-9644638-9871666?psc=1
# Scraping: https://www.amazon.in/Samsung-Storage-Display-Charging-Security/dp/B0DFY3XCB6/ref=zg_bs_g_electronics_d_sccl_1/257-9644638-9871666?psc=1
# Scraping: https://www.amazon.in/realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F18Y9YMX/ref=zg_bs_g_electronics_d_sccl_2/257-9644638-9871666?psc=1
# Scraping: https://www.amazon.in/realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F18Y9YMX/ref=zg_bs_g_electronics_d_sccl_2/257-9644638-9871666?psc=1
# Scraping: https://www.amazon.in/realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F1XMGQSP/ref=zg_bs_g_electronics_d_sccl_3/257-9644638-9871666?psc=1
# Scraping: https://www.amazon.in/realme-Dimensity-Long-Lasting-Top-Tier-Waterproof/dp/B0F1XMGQSP/ref=zg_bs_g_electronics_d_sccl_3/257-9644638-9871666?psc=1
# ...
